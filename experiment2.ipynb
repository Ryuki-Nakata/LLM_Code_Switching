# %%
import json
with open("api_key.json", "r") as f:
    api_key_json = json.load(f)

openai_key = api_key_json["openai"]

# %%
from openai import OpenAI

client = OpenAI(api_key=openai_key)

# %%
with open("experiment2_prompt.txt", "r", encoding="utf-8") as f:
    experiment2_system_prompt = f.read()

# %%
import json
with open("questions.json", "r", encoding="utf-8") as f:
    questions_data = json.load(f)

questions_in_japanese = questions_data["Japanese"]
questions_in_english = questions_data["English"]

# %%
#日本語で質問
answers = {}
for question in questions_in_japanese.values():
    resp = client.chat.completions.create(
        model="gpt-5-mini",
        messages=[
            {"role": "system", "content": experiment2_system_prompt},
            {"role": "user", "content": question}
        ],
    )
    answers[question] = resp.choices[0].message.content

with open("experiment2_answers_j_j.json", "w", encoding="utf-8") as f:
    json.dump(answers, f, ensure_ascii=False, indent=4)

# %%
#英語で質問
answers = {}
for question in questions_in_english.values():
    resp = client.chat.completions.create(
        model="gpt-5-mini",
        messages=[
            {"role": "system", "content": experiment2_system_prompt},
            {"role": "user", "content": question}
        ],
    )
    answers[question] = resp.choices[0].message.content

with open("experiment2_answers_j_e.json", "w", encoding="utf-8") as f:
    json.dump(answers, f, ensure_ascii=False, indent=4)
